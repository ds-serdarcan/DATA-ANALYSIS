# %%
import numpy as np
import pandas as pd

# %%
df_sales = pd.read_csv("../../Downloads/sales_082020.csv")

# %%
df_currency = pd.read_csv("../../Downloads/currency_rates_082020_EUR.csv")

# %%
len(df_sales)
# Out:
# 237671

# %%
df_sales.head()
# Out:
#      buyer_id buyer_country seller_id seller_country  product_code  \
# 0  qzpjsi9t0o            GB  6oufpaot             GB  ydecnydr6obf
# 1  o79pns1qwo            GB  50xki2yg             GB  38chj507o6h2
# 2  sjgbjdkhqx            GB  50xki2yg             GB  i9ynyxj5tdp8
# 3  o79pns1qwo            GB  s0p322hh             GB  t50xe7moye8v
# 4  o79pns1qwo            GB  dpkx192v             GB  hp4r9bjq68af
#
#            category             brand currency  price        date
# 0           Dresses               NaN      GBP  19.11  2020-08-03
# 1         Outerwear  Adidas Originals      GBP  15.92  2020-08-09
# 2       Tops - Mens               NaN      GBP   6.37  2020-08-07
# 3       Tops - Mens          Berghaus      GBP  25.27  2020-08-09
# 4  Bottoms - Womens               NaN      GBP   8.90  2020-08-09

# %%
df_sales["category"].value_counts()
# Out:
# Tops - Womens        45450
# Tops - Mens          32611
# Bottoms - Womens     30001
# Shoes                21764
# Accessories          21153
# Dresses              19238
# Jewellery            14923
# Beauty                8746
# Other                 6599
# Outerwear             6321
# Bottoms - Mens        5763
# Lingerie              5301
# Outerwear - Mens      4156
# Tech                  3496
# Home                  3477
# Music                 2510
# Kids                  2135
# Art                   1777
# Books & magazines     1081
# Film                   466
# Sports equipment       413
# Underwear              177
# Transportation          90
# UNSPECIFIED              7
# Name: category, dtype: int64

# %%
df_currency.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 220 entries, 0 to 219
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   currency  220 non-null    object
#  1   date      220 non-null    object
#  2   rate      220 non-null    float64
#  3   date2     220 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), object(2)
# memory usage: 7.0+ KB

# %%
df_currency.nunique()
# Out:
# currency     22
# date         10
# rate        199
# date2        10
# dtype: int64

# %%
df_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 237671 entries, 0 to 237670
# Data columns (total 11 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   buyer_id        237671 non-null  object
#  1   buyer_country   237671 non-null  object
#  2   seller_id       237671 non-null  object
#  3   seller_country  237671 non-null  object
#  4   product_code    237671 non-null  object
#  5   category        237655 non-null  object
#  6   brand           119330 non-null  object
#  7   currency        237671 non-null  object
#  8   price           237671 non-null  float64
#  9   date            237671 non-null  object
#  10  date2           237671 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), object(9)
# memory usage: 19.9+ MB

# %%
df_sales.shape
# Out:
# (237671, 11)

# %%
len(df_sales["seller_id"].unique())
# Out:
# 114227

# %%
df_sales["seller_id"].nunique()
# Out:
# 114227

# %%
df_sales[df_sales.currency=="EUR"].sample(10)
# Out:
#           buyer_id buyer_country seller_id seller_country  product_code  \
# 198880  vi22icoeus            IT  akdbr54o             IT  6pwll1f3znju
# 213739  7z167n2mvb            IE  h5plx9fo             IE  ufski5akg3ko
# 84382   6l561shurx            IE  06cbgrwe             IE  4pblcyal8sux
# 233619  zzqc8ms114            IE  onv6q31s             IE  pv4oeaa6mrbo
# 104807  mp1ujgbjxd            IE  x7oc9tge             IE  apjc2pcx2xt2
# 168322  bak8omxktk            FR  cgn77w2o             IT  pwt7kwm952mq
# 52920   wold3nnvv6            IT  8f5tn87m             IT  rf8v3ic33po8
# 209168  w2ax3qy8qu            IE  ueb17tou             IE  q94lkeratg4l
# 215443  8i102v8mel            IE  d1oqk7cr             IE  bj1n1e576acg
# 106316  a0i6yv6oja            IE  xoovkrhy             IE  16slpbnp8eui
#
#                 category brand currency  price        date
# 198880          Lingerie   NaN      EUR  32.05  2020-08-06
# ...

# %%
df_sales.sample(10)
# Out:
#           buyer_id buyer_country seller_id seller_country  product_code  \
# 172719  d3kkaxog69            GB  sqetolb9             GB  g51gna6u0gro
# 132902  ag63bgq1pg            US  8vzyzwxg             US  f18p7qtvepwq
# 174359  kph74hbouq            US  zorb7uo7             US  3lnua15l6zdk
# 64080   wenkceuugm            US  zqa8ziys             US  2wclyy7xvnbe
# 134689  bimr6i3cpf            US  ettodq16             US  8hisrp30obx5
# 125224  ksh8spbf1n            GB  x7vi9pd8             GB  1g9lqnvdrbjs
# 174363  su6cfahnrd            US  rezf6q76             US  tywtrsavpo7x
# 128230  5ev1cgk10t            GB  oe053vf6             GB  xwzuu5j1rk2g
# 64957   57l8gou9yq            US  g2co60kn             US  ucml2lpc4wtw
# 73541   rsojc1v04r            GB  w5o09g4k             GB  fajn1pnmfen9
#
#              category               brand currency   price        date
# 172719    Tops - Mens            Champion      GBP   18.19  2020-08-07
# ...

# %%
df_sales.currency.unique()
# Out:
# array(['GBP', 'USD', 'AUD', 'EUR', 'CAD', 'NZD', 'HKD', 'CHF', 'SEK',
#        'DKK', 'ILS', 'PLN', 'THB', 'MXN', 'JPY', 'NOK', 'SGD', 'MYR',
#        'TWD', 'HUF', 'CZK', 'BRL'], dtype=object)

# %%
df_currency.shape
# Out:
# (220, 3)

# %%
df_currency.head()
# Out:
#   currency      date  rate
# 0      EUR  8/1/2020   1.0
# 1      EUR  8/2/2020   1.0
# 2      EUR  8/3/2020   1.0
# 3      EUR  8/4/2020   1.0
# 4      EUR  8/5/2020   1.0

# %%
df_sales.head()
# Out:
#      buyer_id buyer_country seller_id seller_country  product_code  \
# 0  qzpjsi9t0o            GB  6oufpaot             GB  ydecnydr6obf
# 1  o79pns1qwo            GB  50xki2yg             GB  38chj507o6h2
# 2  sjgbjdkhqx            GB  50xki2yg             GB  i9ynyxj5tdp8
# 3  o79pns1qwo            GB  s0p322hh             GB  t50xe7moye8v
# 4  o79pns1qwo            GB  dpkx192v             GB  hp4r9bjq68af
#
#            category             brand currency  price        date
# 0           Dresses               NaN      GBP  19.11  2020-08-03
# 1         Outerwear  Adidas Originals      GBP  15.92  2020-08-09
# 2       Tops - Mens               NaN      GBP   6.37  2020-08-07
# 3       Tops - Mens          Berghaus      GBP  25.27  2020-08-09
# 4  Bottoms - Womens               NaN      GBP   8.90  2020-08-09

# %%
df_currency.head()
# Out:
#   currency      date  rate
# 0      EUR  8/1/2020   1.0
# 1      EUR  8/2/2020   1.0
# 2      EUR  8/3/2020   1.0
# 3      EUR  8/4/2020   1.0
# 4      EUR  8/5/2020   1.0

# %%
df_currency.head()
# Out:
#   currency      date  rate
# 0      EUR  8/1/2020   1.0
# 1      EUR  8/2/2020   1.0
# 2      EUR  8/3/2020   1.0
# 3      EUR  8/4/2020   1.0
# 4      EUR  8/5/2020   1.0

# %%
df_currency[(df_sales.currency==df_currency.currency) & (df_sales.date == df_currency.date)]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15168/3615258170.py in <module>
# ----> 1 df_currency[(df_sales.currency==df_currency.currency) & (df_sales.date == df_currency.date)]
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      67         other = item_from_zerodim(other)
#      68
# ---> 69         return method(self, other)
#      70
#      71     return new_method
#
# ~\anaconda3\lib\site-packages\pandas\core\arraylike.py in __eq__(self, other)
#      30     @unpack_zerodim_and_defer("__eq__")
#      31     def __eq__(self, other):
# ---> 32         return self._cmp_method(other, operator.eq)
#      33
#      34     @unpack_zerodim_and_defer("__ne__")
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in _cmp_method(self, other, op)
#    5494
# ...

# %%
pd.merge(df_sales,df_currency,on=["currency"],how="left")
# Out:
#            buyer_id buyer_country seller_id seller_country  product_code  \
# 0        qzpjsi9t0o            GB  6oufpaot             GB  ydecnydr6obf
# 1        qzpjsi9t0o            GB  6oufpaot             GB  ydecnydr6obf
# 2        qzpjsi9t0o            GB  6oufpaot             GB  ydecnydr6obf
# 3        qzpjsi9t0o            GB  6oufpaot             GB  ydecnydr6obf
# 4        qzpjsi9t0o            GB  6oufpaot             GB  ydecnydr6obf
# ...             ...           ...       ...            ...           ...
# 2376705  z09h7w9zcd            US  0au7baxi             US  0r1qni2g1zi4
# 2376706  z09h7w9zcd            US  0au7baxi             US  0r1qni2g1zi4
# 2376707  z09h7w9zcd            US  0au7baxi             US  0r1qni2g1zi4
# 2376708  z09h7w9zcd            US  0au7baxi             US  0r1qni2g1zi4
# 2376709  z09h7w9zcd            US  0au7baxi             US  0r1qni2g1zi4
#
#         category brand currency   price      date_x     date_y      rate
# ...

# %%
pd.concat([df_sales,df_currency],iaxis=0)
# Out:
#        buyer_id buyer_country seller_id seller_country  product_code  \
# 0    qzpjsi9t0o            GB  6oufpaot             GB  ydecnydr6obf
# 1    o79pns1qwo            GB  50xki2yg             GB  38chj507o6h2
# 2    sjgbjdkhqx            GB  50xki2yg             GB  i9ynyxj5tdp8
# 3    o79pns1qwo            GB  s0p322hh             GB  t50xe7moye8v
# 4    o79pns1qwo            GB  dpkx192v             GB  hp4r9bjq68af
# ..          ...           ...       ...            ...           ...
# 215         NaN           NaN       NaN            NaN           NaN
# 216         NaN           NaN       NaN            NaN           NaN
# 217         NaN           NaN       NaN            NaN           NaN
# 218         NaN           NaN       NaN            NaN           NaN
# 219         NaN           NaN       NaN            NaN           NaN
#
#              category             brand currency  price        date    rate
# ...

# %%
df_sales.groupby("currency").sum()
# Out:
#                price
# currency
# AUD        325563.44
# BRL            34.92
# CAD         65101.80
# CHF          5974.74
# CZK          3923.18
# DKK          4853.44
# EUR        275837.69
# GBP       3449449.49
# HKD           108.13
# HUF         36919.18
# ILS            33.80
# JPY         39722.66
# MXN           389.47
# MYR           263.30
# NOK          3168.34
# NZD         10532.85
# PLN           693.36
# SEK         10903.22
# SGD           443.37
# THB          1223.72
# TWD            42.81
# USD       2504544.82

# %%
len(df_sales.seller_id.unique())
# Out:
# 114227

# %%
df_sales.seller_id.unique().shape
# Out:
# (114227,)

# %%
df_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 237671 entries, 0 to 237670
# Data columns (total 10 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   buyer_id        237671 non-null  object
#  1   buyer_country   237671 non-null  object
#  2   seller_id       237671 non-null  object
#  3   seller_country  237671 non-null  object
#  4   product_code    237671 non-null  object
#  5   category        237655 non-null  object
#  6   brand           119330 non-null  object
#  7   currency        237671 non-null  object
#  8   price           237671 non-null  float64
#  9   date            237671 non-null  object
# dtypes: float64(1), object(9)
# memory usage: 18.1+ MB

# %%
len(df_sales.columns)
# Out:
# 10

# %%
df_sales.columns
# Out:
# Index(['buyer_id', 'buyer_country', 'seller_id', 'seller_country',
#        'product_code', 'category', 'brand', 'currency', 'price', 'date'],
#       dtype='object')

# %%
df_sales.head()
# Out:
#      buyer_id buyer_country seller_id seller_country  product_code  \
# 0  qzpjsi9t0o            GB  6oufpaot             GB  ydecnydr6obf
# 1  o79pns1qwo            GB  50xki2yg             GB  38chj507o6h2
# 2  sjgbjdkhqx            GB  50xki2yg             GB  i9ynyxj5tdp8
# 3  o79pns1qwo            GB  s0p322hh             GB  t50xe7moye8v
# 4  o79pns1qwo            GB  dpkx192v             GB  hp4r9bjq68af
#
#            category             brand currency  price        date
# 0           Dresses               NaN      GBP  19.11  2020-08-03
# 1         Outerwear  Adidas Originals      GBP  15.92  2020-08-09
# 2       Tops - Mens               NaN      GBP   6.37  2020-08-07
# 3       Tops - Mens          Berghaus      GBP  25.27  2020-08-09
# 4  Bottoms - Womens               NaN      GBP   8.90  2020-08-09

# %%
df_sales.groupby("brand").count().idxmax()
# Out:
# buyer_id          Nike
# buyer_country     Nike
# seller_id         Nike
# seller_country    Nike
# product_code      Nike
# category          Nike
# currency          Nike
# price             Nike
# date              Nike
# dtype: object

# %%
df_sales.groupby("brand").count().max()
# Out:
# buyer_id          9575
# buyer_country     9575
# seller_id         9575
# seller_country    9575
# product_code      9575
# category          9575
# currency          9575
# price             9575
# date              9575
# dtype: int64

# %%
df_sales.brand.value_counts()
# Out:
# Nike                  9575
# Brandy Melville       5065
# Topshop               4561
# PrettyLittle Thing    4136
# Adidas                3905
#                       ...
# Preen                    1
# Wacoal                   1
# Shu Uemura               1
# Parker                   1
# Vita Fede                1
# Name: brand, Length: 1134, dtype: int64

# %%
df_sales.head()
# Out:
#      buyer_id buyer_country seller_id seller_country  product_code  \
# 0  qzpjsi9t0o            GB  6oufpaot             GB  ydecnydr6obf
# 1  o79pns1qwo            GB  50xki2yg             GB  38chj507o6h2
# 2  sjgbjdkhqx            GB  50xki2yg             GB  i9ynyxj5tdp8
# 3  o79pns1qwo            GB  s0p322hh             GB  t50xe7moye8v
# 4  o79pns1qwo            GB  dpkx192v             GB  hp4r9bjq68af
#
#            category             brand currency  price        date
# 0           Dresses               NaN      GBP  19.11  2020-08-03
# 1         Outerwear  Adidas Originals      GBP  15.92  2020-08-09
# 2       Tops - Mens               NaN      GBP   6.37  2020-08-07
# 3       Tops - Mens          Berghaus      GBP  25.27  2020-08-09
# 4  Bottoms - Womens               NaN      GBP   8.90  2020-08-09

# %%
df_sales[df_sales.category=="Jewellery"].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14923 entries, 23 to 237643
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   buyer_id        14923 non-null  object
#  1   buyer_country   14923 non-null  object
#  2   seller_id       14923 non-null  object
#  3   seller_country  14923 non-null  object
#  4   product_code    14923 non-null  object
#  5   category        14923 non-null  object
#  6   brand           1398 non-null   object
#  7   currency        14923 non-null  object
#  8   price           14923 non-null  float64
#  9   date            14923 non-null  object
# dtypes: float64(1), object(9)
# memory usage: 1.3+ MB

# %%
df_sales[df_sales.category=="Jewellery"].isnull().sum()
# Out:
# buyer_id              0
# buyer_country         0
# seller_id             0
# seller_country        0
# product_code          0
# category              0
# brand             13525
# currency              0
# price                 0
# date                  0
# dtype: int64

# %%
df_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 237671 entries, 0 to 237670
# Data columns (total 10 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   buyer_id        237671 non-null  object
#  1   buyer_country   237671 non-null  object
#  2   seller_id       237671 non-null  object
#  3   seller_country  237671 non-null  object
#  4   product_code    237671 non-null  object
#  5   category        237655 non-null  object
#  6   brand           119330 non-null  object
#  7   currency        237671 non-null  object
#  8   price           237671 non-null  float64
#  9   date            237671 non-null  object
# dtypes: float64(1), object(9)
# memory usage: 18.1+ MB

# %%
((df_sales.brand.value_counts().values <= 55) & (df_sales.brand.value_counts().values >= 35)).sum()
# Out:
# 81

# %%
df_sales.head()
# Out:
#      buyer_id buyer_country seller_id seller_country  product_code  \
# 0  qzpjsi9t0o            GB  6oufpaot             GB  ydecnydr6obf
# 1  o79pns1qwo            GB  50xki2yg             GB  38chj507o6h2
# 2  sjgbjdkhqx            GB  50xki2yg             GB  i9ynyxj5tdp8
# 3  o79pns1qwo            GB  s0p322hh             GB  t50xe7moye8v
# 4  o79pns1qwo            GB  dpkx192v             GB  hp4r9bjq68af
#
#            category             brand currency  price        date
# 0           Dresses               NaN      GBP  19.11  2020-08-03
# 1         Outerwear  Adidas Originals      GBP  15.92  2020-08-09
# 2       Tops - Mens               NaN      GBP   6.37  2020-08-07
# 3       Tops - Mens          Berghaus      GBP  25.27  2020-08-09
# 4  Bottoms - Womens               NaN      GBP   8.90  2020-08-09

# %%
df_sales.buyer_country.value_counts()
# Out:
# GB     134704
# US      82661
# AU       7868
# IE       4046
# RoW      2880
# IT       2532
# CA       2247
# DE        466
# FR        267
# Name: buyer_country, dtype: int64

# %%
df_sales.groupby("buyer_country").count()
# Out:
#                buyer_id  seller_id  seller_country  product_code  category  \
# buyer_country
# AU                 7868       7868            7868          7868      7868
# CA                 2247       2247            2247          2247      2246
# DE                  466        466             466           466       466
# FR                  267        267             267           267       267
# GB               134704     134704          134704        134704    134696
# IE                 4046       4046            4046          4046      4046
# IT                 2532       2532            2532          2532      2531
# RoW                2880       2880            2880          2880      2880
# US                82661      82661           82661         82661     82655
#
#                brand  currency   price    date
# buyer_country
# AU               305      7868    7868    7868
# CA               235      2247    2247    2247
# ...

# %%
df_sales.category.value_counts()
# Out:
# Tops - Womens        45450
# Tops - Mens          32611
# Bottoms - Womens     30001
# Shoes                21764
# Accessories          21153
# Dresses              19238
# Jewellery            14923
# Beauty                8746
# Other                 6599
# Outerwear             6321
# Bottoms - Mens        5763
# Lingerie              5301
# Outerwear - Mens      4156
# Tech                  3496
# Home                  3477
# Music                 2510
# Kids                  2135
# Art                   1777
# Books & magazines     1081
# Film                   466
# Sports equipment       413
# Underwear              177
# Transportation          90
# UNSPECIFIED              7
# Name: category, dtype: int64

# %%
df_sales[df_sales.category=="Shoes"].buyer_country.value_counts()
# Out:
# GB     13585
# US      6391
# AU       658
# IT       329
# IE       315
# RoW      296
# CA       115
# FR        44
# DE        31
# Name: buyer_country, dtype: int64

# %%
df_sales[(df_sales.category=="Shoes") & (df_sales.buyer_country=="AU")].shape
# Out:
# (658, 10)

# %%
df_sales.head()
# Out:
#      buyer_id buyer_country seller_id seller_country  product_code  \
# 0  qzpjsi9t0o            GB  6oufpaot             GB  ydecnydr6obf
# 1  o79pns1qwo            GB  50xki2yg             GB  38chj507o6h2
# 2  sjgbjdkhqx            GB  50xki2yg             GB  i9ynyxj5tdp8
# 3  o79pns1qwo            GB  s0p322hh             GB  t50xe7moye8v
# 4  o79pns1qwo            GB  dpkx192v             GB  hp4r9bjq68af
#
#            category             brand currency  price        date
# 0           Dresses               NaN      GBP  19.11  2020-08-03
# 1         Outerwear  Adidas Originals      GBP  15.92  2020-08-09
# 2       Tops - Mens               NaN      GBP   6.37  2020-08-07
# 3       Tops - Mens          Berghaus      GBP  25.27  2020-08-09
# 4  Bottoms - Womens               NaN      GBP   8.90  2020-08-09

# %%
round(df_sales[(df_sales.buyer_country=="GB") & (df_sales.seller_country=="GB")]["price"].sum())
# Out:
# 3184496

# %%
df_sales.category.unique()
# Out:
# array(['Dresses', 'Outerwear', 'Tops - Mens', 'Bottoms - Womens',
#        'Tops - Womens', 'Outerwear - Mens', 'Accessories', 'Jewellery',
#        'Other', 'Film', 'Art', 'Music', 'Shoes', 'Lingerie',
#        'Bottoms - Mens', 'Home', 'Tech', 'Beauty', 'Sports equipment',
#        'Kids', 'Transportation', 'Books & magazines', 'Underwear',
#        'UNSPECIFIED', nan], dtype=object)

# %%
a = len(df_sales[(df_sales.seller_country=="US")])

# %%
len(df_sales[(df_sales.buyer_country=="US") & (df_sales.seller_country=="US")]) / a*100
# Out:
# 98.23044415486353

# %%
df_sales.seller_country.value_counts()
# Out:
# GB     139203
# US      82111
# AU       7592
# IE       3014
# IT       2464
# CA       1971
# RoW      1128
# DE        135
# FR         53
# Name: seller_country, dtype: int64

# %%
len(df_sales[(df_sales.buyer_country=="US") & (df_sales.seller_country=="US")])
# Out:
# 80658

# %%
df_sales.head()
# Out:
#      buyer_id buyer_country seller_id seller_country  product_code  \
# 0  qzpjsi9t0o            GB  6oufpaot             GB  ydecnydr6obf
# 1  o79pns1qwo            GB  50xki2yg             GB  38chj507o6h2
# 2  sjgbjdkhqx            GB  50xki2yg             GB  i9ynyxj5tdp8
# 3  o79pns1qwo            GB  s0p322hh             GB  t50xe7moye8v
# 4  o79pns1qwo            GB  dpkx192v             GB  hp4r9bjq68af
#
#            category             brand currency  price        date
# 0           Dresses               NaN      GBP  19.11  2020-08-03
# 1         Outerwear  Adidas Originals      GBP  15.92  2020-08-09
# 2       Tops - Mens               NaN      GBP   6.37  2020-08-07
# 3       Tops - Mens          Berghaus      GBP  25.27  2020-08-09
# 4  Bottoms - Womens               NaN      GBP   8.90  2020-08-09

# %%
df_currency.head()
# Out:
#   currency      date  rate
# 0      EUR  8/1/2020   1.0
# 1      EUR  8/2/2020   1.0
# 2      EUR  8/3/2020   1.0
# 3      EUR  8/4/2020   1.0
# 4      EUR  8/5/2020   1.0

# %%
df_currency["date2"] = pd.to_datetime(df_currency.date)

# %%
df_currency.head()
# Out:
#   currency      date  rate      date2
# 0      EUR  8/1/2020   1.0 2020-08-01
# 1      EUR  8/2/2020   1.0 2020-08-02
# 2      EUR  8/3/2020   1.0 2020-08-03
# 3      EUR  8/4/2020   1.0 2020-08-04
# 4      EUR  8/5/2020   1.0 2020-08-05

# %%
df_sales["date2"] = pd.to_datetime(df_sales.date)

# %%
pd.merge(df_sales,df_currency,on=["date2","currency"],how="left").info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 237671 entries, 0 to 237670
# Data columns (total 13 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   buyer_id        237671 non-null  object
#  1   buyer_country   237671 non-null  object
#  2   seller_id       237671 non-null  object
#  3   seller_country  237671 non-null  object
#  4   product_code    237671 non-null  object
#  5   category        237655 non-null  object
#  6   brand           119330 non-null  object
#  7   currency        237671 non-null  object
#  8   price           237671 non-null  float64
#  9   date_x          237671 non-null  object
#  10  date2           237671 non-null  datetime64[ns]
#  11  date_y          237671 non-null  object
#  12  rate            237671 non-null  float64
# dtypes: datetime64[ns](1), float64(2), object(10)
# memory usage: 25.4+ MB

# %%
df = pd.merge(df_sales,df_currency,on=["date2","currency"],how="left")

# %%
df.head()
# Out:
#      buyer_id buyer_country seller_id seller_country  product_code  \
# 0  qzpjsi9t0o            GB  6oufpaot             GB  ydecnydr6obf
# 1  o79pns1qwo            GB  50xki2yg             GB  38chj507o6h2
# 2  sjgbjdkhqx            GB  50xki2yg             GB  i9ynyxj5tdp8
# 3  o79pns1qwo            GB  s0p322hh             GB  t50xe7moye8v
# 4  o79pns1qwo            GB  dpkx192v             GB  hp4r9bjq68af
#
#            category             brand currency  price      date_x      date2  \
# 0           Dresses               NaN      GBP  19.11  2020-08-03 2020-08-03
# 1         Outerwear  Adidas Originals      GBP  15.92  2020-08-09 2020-08-09
# 2       Tops - Mens               NaN      GBP   6.37  2020-08-07 2020-08-07
# 3       Tops - Mens          Berghaus      GBP  25.27  2020-08-09 2020-08-09
# 4  Bottoms - Womens               NaN      GBP   8.90  2020-08-09 2020-08-09
#
#      date_y     rate
# 0  8/3/2020  0.89935
# 1  8/9/2020  0.90278
# 2  8/7/2020  0.90286
# ...

# %%
df["price2"]=df.price*df.rate

# %%
df.price2.sum()
# Out:
# 25111216.067888867

# %%
df.groupby("brand").price2.mean().max()
# Out:
# 345.99581541666663

# %%
df.groupby("brand").price2.mean().idxmax()
# Out:
# 'Goyard'

# %%
df.groupby("brand").price2.describe()
# Out:
#                  count       mean        std        min        25%        50%  \
# brand
# & Other Stories  151.0  28.374667  47.220857   0.944318  13.520194  19.698792
# 032c              11.0  32.253589  55.061803   1.308451   5.045741  13.442394
# 11 Degrees        33.0  11.832631   7.760096   0.975040   8.095275  10.255978
# 1822 Denim         8.0  19.990219  14.992714   3.457647  10.065819  17.824124
# 3.1 Phillip Lim   10.0  39.229189  51.916189   7.768193  12.948953  18.166523
# ...                ...        ...        ...        ...        ...        ...
# ghd               35.0  50.690025  34.564750   5.119216  31.979301  47.296305
# kensie             1.0  27.841130        NaN  27.841130  27.841130  27.841130
# liquid blue       52.0  54.714742  28.730321   6.553648  33.183028  52.894999
# mixxmix           12.0  22.165552  12.176488   6.506893  13.311262  20.578833
# philosophy         4.0  31.385162  13.626875  16.690392  24.021817  29.882824
#
# ...

# %%
df_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 237671 entries, 0 to 237670
# Data columns (total 11 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   buyer_id        237671 non-null  object
#  1   buyer_country   237671 non-null  object
#  2   seller_id       237671 non-null  object
#  3   seller_country  237671 non-null  object
#  4   product_code    237671 non-null  object
#  5   category        237655 non-null  object
#  6   brand           119330 non-null  object
#  7   currency        237671 non-null  object
#  8   price           237671 non-null  float64
#  9   date            237671 non-null  object
#  10  date2           237671 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), object(9)
# memory usage: 19.9+ MB

# %%
df.head()
# Out:
#      buyer_id buyer_country seller_id seller_country  product_code  \
# 0  qzpjsi9t0o            GB  6oufpaot             GB  ydecnydr6obf
# 1  o79pns1qwo            GB  50xki2yg             GB  38chj507o6h2
# 2  sjgbjdkhqx            GB  50xki2yg             GB  i9ynyxj5tdp8
# 3  o79pns1qwo            GB  s0p322hh             GB  t50xe7moye8v
# 4  o79pns1qwo            GB  dpkx192v             GB  hp4r9bjq68af
#
#            category             brand currency  price      date_x      date2  \
# 0           Dresses               NaN      GBP  19.11  2020-08-03 2020-08-03
# 1         Outerwear  Adidas Originals      GBP  15.92  2020-08-09 2020-08-09
# 2       Tops - Mens               NaN      GBP   6.37  2020-08-07 2020-08-07
# 3       Tops - Mens          Berghaus      GBP  25.27  2020-08-09 2020-08-09
# 4  Bottoms - Womens               NaN      GBP   8.90  2020-08-09 2020-08-09
#
#      date_y     rate     price2
# 0  8/3/2020  0.89935  17.186578
# 1  8/9/2020  0.90278  14.372258
# ...

# %%
len(df_sales[(df_sales.buyer_country=="US") & (df_sales.seller_country=="US")]) / a*100

# %%
df[(df.buyer_country=="US")&(df.seller_country=="US")].price.sum() / df[(df.seller_country=="US")].price.sum()
# Out:
# 0.9598216537130441

# %%
df_sales.head()
# Out:
#      buyer_id buyer_country seller_id seller_country  product_code  \
# 0  qzpjsi9t0o            GB  6oufpaot             GB  ydecnydr6obf
# 1  o79pns1qwo            GB  50xki2yg             GB  38chj507o6h2
# 2  sjgbjdkhqx            GB  50xki2yg             GB  i9ynyxj5tdp8
# 3  o79pns1qwo            GB  s0p322hh             GB  t50xe7moye8v
# 4  o79pns1qwo            GB  dpkx192v             GB  hp4r9bjq68af
#
#            category             brand currency  price       date
# 0           Dresses               NaN      GBP  19.11 2020-08-03
# 1         Outerwear  Adidas Originals      GBP  15.92 2020-08-09
# 2       Tops - Mens               NaN      GBP   6.37 2020-08-07
# 3       Tops - Mens          Berghaus      GBP  25.27 2020-08-09
# 4  Bottoms - Womens               NaN      GBP   8.90 2020-08-09

# %%
df_sales["date"] = pd.to_datetime(df_sales["date"])

# %%
df_currency.head()
# Out:
#   currency       date  rate
# 0      EUR 2020-08-01   1.0
# 1      EUR 2020-08-02   1.0
# 2      EUR 2020-08-03   1.0
# 3      EUR 2020-08-04   1.0
# 4      EUR 2020-08-05   1.0

# %%
df_currency["date"] = pd.to_datetime(df_currency["date"])

# %%
df = pd.merge(df_sales,df_currency,on=["currency","date"],how="inner")
df.head()
# Out:
#      buyer_id buyer_country seller_id seller_country  product_code  \
# 0  qzpjsi9t0o            GB  6oufpaot             GB  ydecnydr6obf
# 1  rd209r8c7c            GB  9p2ansc9             GB  wpxxf59cq7pc
# 2  pqbcrl8azx            GB  r9zmzem8             GB  ua9mmn86wsqy
# 3  j5en1rwmxp            GB  3o2nz88r             GB  tduo2uy8iszl
# 4  kjdezxeh1l            GB  7g56ublf             GB  39o00tcu89zq
#
#            category             brand currency  price       date     rate
# 0           Dresses               NaN      GBP  19.11 2020-08-03  0.89935
# 1  Outerwear - Mens  Adidas Originals      GBP  24.91 2020-08-03  0.89935
# 2     Tops - Womens               NaN      GBP  19.31 2020-08-03  0.89935
# 3  Bottoms - Womens  Urban Outfitters      GBP  16.98 2020-08-03  0.89935
# 4             Other               NaN      GBP   2.85 2020-08-03  0.89935

# %%
df["total_rate"] = df.price / df.rate

# %%
df.head()
# Out:
#      buyer_id buyer_country seller_id seller_country  product_code  \
# 0  qzpjsi9t0o            GB  6oufpaot             GB  ydecnydr6obf
# 1  rd209r8c7c            GB  9p2ansc9             GB  wpxxf59cq7pc
# 2  pqbcrl8azx            GB  r9zmzem8             GB  ua9mmn86wsqy
# 3  j5en1rwmxp            GB  3o2nz88r             GB  tduo2uy8iszl
# 4  kjdezxeh1l            GB  7g56ublf             GB  39o00tcu89zq
#
#            category             brand currency  price       date     rate  \
# 0           Dresses               NaN      GBP  19.11 2020-08-03  0.89935
# 1  Outerwear - Mens  Adidas Originals      GBP  24.91 2020-08-03  0.89935
# 2     Tops - Womens               NaN      GBP  19.31 2020-08-03  0.89935
# 3  Bottoms - Womens  Urban Outfitters      GBP  16.98 2020-08-03  0.89935
# 4             Other               NaN      GBP   2.85 2020-08-03  0.89935
#
#    total_rate
# 0   21.248680
# 1   27.697782
# 2   21.471062
# 3   18.880302
# 4    3.168955

# %%
round(df.total_rate.sum())
# Out:
# 6471511

# %%
6.471.511

# %%
df.brand.value_counts()
# Out:
# Nike                  9575
# Brandy Melville       5065
# Topshop               4561
# PrettyLittle Thing    4136
# Adidas                3905
#                       ...
# Filson                   1
# Surf Gypsy               1
# Chaser                   1
# All Things Mochi         1
# KTZ                      1
# Name: brand, Length: 1134, dtype: int64

# %%
df.groupby(["brand"])["total_rate"].sum().sort_values()
# Out:
# brand
# 36572                      0.950199
# 360 Cashmere               2.852719
# Popular Sports             4.452175
# Ann Demeulemeester         5.262487
# butter LONDON              5.457968
#                           ...
# Dr. Martens            81491.623673
# Brandy Melville        87735.664806
# American Vintage       89939.908652
# Adidas                114211.542782
# Nike                  385022.414067
# Name: total_rate, Length: 1134, dtype: float64

# %%
df_sales.head()
# Out:
#      buyer_id buyer_country seller_id seller_country  product_code  \
# 0  qzpjsi9t0o            GB  6oufpaot             GB  ydecnydr6obf
# 1  o79pns1qwo            GB  50xki2yg             GB  38chj507o6h2
# 2  sjgbjdkhqx            GB  50xki2yg             GB  i9ynyxj5tdp8
# 3  o79pns1qwo            GB  s0p322hh             GB  t50xe7moye8v
# 4  o79pns1qwo            GB  dpkx192v             GB  hp4r9bjq68af
#
#            category             brand currency  price       date
# 0           Dresses               NaN      GBP  19.11 2020-08-03
# 1         Outerwear  Adidas Originals      GBP  15.92 2020-08-09
# 2       Tops - Mens               NaN      GBP   6.37 2020-08-07
# 3       Tops - Mens          Berghaus      GBP  25.27 2020-08-09
# 4  Bottoms - Womens               NaN      GBP   8.90 2020-08-09

# %%
df_sales["category"]

# %%
df_sales[(df_sales["category"] == "Jewellery") & (df_sales["brand"].isnull())]["product_code"].nunique()
# Out:
# 10931

# %%
((df_sales.brand.value_counts() <= 55) & (df_sales.brand.value_counts() >= 35)).sum()
# Out:
# 81

# %%
df_sales[(df_sales["category"] == "Shoes") & (df_sales["buyer_country"]=="AU")].shape
# Out:
# (658, 10)

# %%
df.groupby("brand")["total_rate"].mean().idxmax()
# Out:
# 'Goyard'

# %%
df.groupby("brand")["total_rate"].mean().max()
# Out:
# 338.92693604836

# %%
df.groupby("brand")["total_rate"].mean().sort_values()
# Out:
# brand
# 36572               0.950199
# 360 Cashmere        0.950906
# Bronica             3.329066
# Max Factor          4.329298
# Popular Sports      4.452175
#                      ...
# Emilio Pucci      214.758636
# TAG Heuer         224.586782
# Craig Green       266.792684
# Loewe             334.530369
# Goyard            338.926936
# Name: total_rate, Length: 1134, dtype: float64

# %%
df_sales.brand.value_counts()
# Out:
# Nike                  9575
# Brandy Melville       5065
# Topshop               4561
# PrettyLittle Thing    4136
# Adidas                3905
#                       ...
# Preen                    1
# Wacoal                   1
# Shu Uemura               1
# Parker                   1
# Vita Fede                1
# Name: brand, Length: 1134, dtype: int64

# %%
df[(df["seller_country"]=="GB") & (df["buyer_country"]=="GB")]["total_rate"].sum()
# Out:
# 3526745.033129233

# %%
3.526.745

# %%
df[(df["seller_country"]=="US") & (df["buyer_country"]=="US")]["total_rate"].sum() / df[df["seller_country"]=="US"]["total_rate"].sum()
# Out:
# 0.9596922067159569

# %%
len(df[(df["seller_country"]=="US") & (df["buyer_country"]=="US")]) / df[df["seller_country"]=="US"].shape[0]
# Out:
# 0.9823044415486354
